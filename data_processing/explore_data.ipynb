# %%
# libraries importing
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Data loading

# %%
path_to_data = 'SKAB/'

# %%
# benchmark files checking
all_files=[]
for root, dirs, files in os.walk(path_to_data):
    for file in files:
        if file.endswith(".csv"):
             all_files.append(os.path.join(root, file))

# %%
# datasets with anomalies loading
list_of_df = [pd.read_csv(file, 
                          sep=';', 
                          index_col='datetime', 
                          parse_dates=True) for file in all_files if 'anomaly-free' not in file]
# anomaly-free df loading
anomaly_free_df = pd.read_csv([file for file in all_files if 'anomaly-free' in file][0], 
                            sep=';', 
                            index_col='datetime', 
                            parse_dates=True)

# %%
anomaly_free_df
# Out:
#                      Accelerometer1RMS  Accelerometer2RMS   Current  Pressure  \
# datetime
# 2020-02-08 13:30:47           0.206030           0.277924  1.810190  0.382638
# 2020-02-08 13:30:48           0.204366           0.275727  2.663170 -0.273216
# 2020-02-08 13:30:49           0.206103           0.278526  2.637580  0.382638
# 2020-02-08 13:30:51           0.204775           0.276948  2.328510  0.382638
# 2020-02-08 13:30:52           0.206052           0.278141  2.534220  0.382638
# ...                                ...                ...       ...       ...
# 2020-02-08 16:16:43           0.195840           0.259540  2.296760  0.382638
# 2020-02-08 16:16:44           0.194596           0.259175  2.264030  0.054711
# 2020-02-08 16:16:45           0.197453           0.259046  0.928891  0.054711
# 2020-02-08 16:16:46           0.193992           0.259874  2.463890  0.382638
# 2020-02-08 16:16:47           0.197630           0.258334  0.893839  0.382638
#
# ...

# %%
(anomaly_free_df == anomaly_free_df.sort_index()).all()
# Out:
# Accelerometer1RMS      True
# Accelerometer2RMS      True
# Current                True
# Pressure               True
# Temperature            True
# Thermocouple           True
# Voltage                True
# Volume Flow RateRMS    True
# dtype: bool

# %%
valve1_data = {file.split('/')[-1]:pd.read_csv(file, sep=';',index_col='datetime',parse_dates=True)
              for file in all_files if 'valve1' in file}

#concatenate data(order in time series by sort_index)
valve1_df = pd.concat(list(valve1_data.values()),axis=0).sort_index()

# %%
valve2_data = {file.split('/')[-1]:pd.read_csv(file, sep=';',index_col='datetime',parse_dates=True)
              for file in all_files if 'valve2' in file}

#concatenate data(order in time series by sort_index)
valve2_df = pd.concat(list(valve2_data.values()),axis=0).sort_index()

# %%
other_anomaly_data = {file.split('/')[-1]:pd.read_csv(file, sep=';',index_col='datetime',parse_dates=True)
              for file in all_files if 'other' in file}

#concatenate data(order in time series by sort_index)
other_anomaly_df = pd.concat(list(other_anomaly_data.values()),axis=0).sort_index()

# %%
valve1_df.isna().any()
# Out:
# Accelerometer1RMS      False
# Accelerometer2RMS      False
# Current                False
# Pressure               False
# Temperature            False
# Thermocouple           False
# Voltage                False
# Volume Flow RateRMS    False
# anomaly                False
# changepoint            False
# dtype: bool

# %%
valve1_df.describe()
# Out:
#        Accelerometer1RMS  Accelerometer2RMS       Current      Pressure  \
# count       18162.000000       18162.000000  18162.000000  18162.000000
# mean            0.027338           0.040546      1.161527      0.063757
# std             0.000527           0.001168      6.529687      0.258569
# min             0.025553           0.037339      0.355411     -1.257000
# 25%             0.026971           0.039761      0.739681      0.054711
# 50%             0.027346           0.040461      0.986919      0.054711
# 75%             0.027722           0.041192      1.202882      0.054711
# max             0.029031           0.053439    242.018000      1.694350
#
#         Temperature  Thermocouple       Voltage  Volume Flow RateRMS  \
# count  18162.000000  18162.000000  18162.000000         18162.000000
# mean      70.208237     25.029187    230.522074            31.284873
# std        2.609608      0.447764     12.666497             1.991863
# ...

# %%
valve2_df.isna().any()
# Out:
# Accelerometer1RMS      False
# Accelerometer2RMS      False
# Current                False
# Pressure               False
# Temperature            False
# Thermocouple           False
# Voltage                False
# Volume Flow RateRMS    False
# anomaly                False
# changepoint            False
# dtype: bool

# %%
valve2_df.describe()
# Out:
#        Accelerometer1RMS  Accelerometer2RMS      Current     Pressure  \
# count        4312.000000        4312.000000  4312.000000  4312.000000
# mean            0.027590           0.039766     1.182498     0.055091
# std             0.000356           0.001214     6.971728     0.264234
# min             0.026455           0.036098     0.383591    -0.929070
# 25%             0.027342           0.038914     0.743011     0.054711
# 50%             0.027594           0.039785     0.984123     0.054711
# 75%             0.027826           0.040611     1.200335     0.054711
# max             0.031339           0.043516   243.829000     1.038490
#
#        Temperature  Thermocouple      Voltage  Volume Flow RateRMS  \
# count  4312.000000   4312.000000  4312.000000          4312.000000
# mean     68.279706     24.236979   230.494986            31.553337
# std       1.072908      0.073683    12.854764             1.175634
# ...

# %%
other_anomaly_df.isna().any()
# Out:
# Accelerometer1RMS      False
# Accelerometer2RMS      False
# Current                False
# Pressure               False
# Temperature            False
# Thermocouple           False
# Voltage                False
# Volume Flow RateRMS    False
# anomaly                False
# changepoint            False
# dtype: bool

# %%
other_anomaly_df.describe()
# Out:
#        Accelerometer1RMS  Accelerometer2RMS       Current      Pressure  \
# count       14985.000000       14985.000000  14985.000000  14985.000000
# mean            0.232301           0.282515      2.376018      0.087843
# std             0.138586           0.145527      5.939308      0.261372
# min             0.000000           0.000000      0.589101     -1.257000
# 25%             0.209521           0.257621      1.829060      0.054711
# 50%             0.228478           0.273493      2.336300      0.054711
# 75%             0.245047           0.291260      2.693860      0.382638
# max             0.722747           0.800498    239.003000      1.366420
#
#         Temperature  Thermocouple       Voltage  Volume Flow RateRMS  \
# count  14985.000000  14985.000000  14985.000000         14985.000000
# mean      87.280220     27.969336    228.291866           109.864931
# std        1.873378      3.319900     12.557712            30.198560
# ...

# %%
all_data = {file.split('/')[-1]:pd.read_csv(file, sep=';',index_col='datetime',parse_dates=True)
              for file in all_files}

#concatenate data(order in time series by sort_index)
all_data = pd.concat(list(all_data.values()),axis=0).sort_index()

# %%
all_data
# Out:
#                      Accelerometer1RMS  Accelerometer2RMS   Current  Pressure  \
# datetime
# 2020-02-08 13:30:47           0.206030           0.277924  1.810190  0.382638
# 2020-02-08 13:30:48           0.204366           0.275727  2.663170 -0.273216
# 2020-02-08 13:30:49           0.206103           0.278526  2.637580  0.382638
# 2020-02-08 13:30:51           0.204775           0.276948  2.328510  0.382638
# 2020-02-08 13:30:52           0.206052           0.278141  2.534220  0.382638
# ...                                ...                ...       ...       ...
# 2020-03-09 17:14:04           0.026853           0.038926  0.740614  0.054711
# 2020-03-09 17:14:05           0.027067           0.038430  0.988875  0.054711
# 2020-03-09 17:14:07           0.027582           0.038836  0.588439  0.054711
# 2020-03-09 17:14:08           0.027406           0.038133  0.989732 -0.273216
# 2020-03-09 17:14:09           0.027102           0.039890  0.558126 -0.273216
#
# ...
